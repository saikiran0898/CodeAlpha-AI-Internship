# %%
while True:
    user = input("You: ").lower()

    if user == "hello":
        print("Bot: Hello! How can I help you?")

    elif user == "how are you":
        print("Bot: I am fine. Thank you!")

    elif user == "your name":
        print("Bot: I am CodeAlpha AI Chatbot.")

    elif user == "bye":
        print("Bot: Goodbye! Have a nice day.")
        break

    else:
        print("Bot: Sorry, I don't understand.")
# Out:
# Bot: Hello! How can I help you?
# Bot: I am fine. Thank you!
# Bot: Sorry, I don't understand.
# Bot: I am CodeAlpha AI Chatbot.
# Bot: Goodbye! Have a nice day.

# %% [markdown]
# # Conclusion
#
# Successfully developed a Rule-Based AI Chatbot using Python.
#
# The chatbot responds to basic user queries using conditional statements (if-elif-else) and terminates when the user enters "bye".

# %%
print("===================================")
print("      Welcome to AI Chatbot")
print("===================================")
# Out:
# ...
#       Welcome to AI Chatbot
# ...
