# %%
from deep_translator import GoogleTranslator

text = "Artificial Intelligence is changing the world."

languages = {
    "Telugu": "te",
    "Hindi": "hi",
    "Tamil": "ta",
    "French": "fr"
}

print("Original Text:", text)
print()

for language, code in languages.items():
    translated = GoogleTranslator(source="en", target=code).translate(text)
    print(f"{language}: {translated}")
# Out:
# Original Text: Artificial Intelligence is changing the world.
#
# Telugu: ఆర్టిఫిషియల్ ఇంటెలిజెన్స్ ప్రపంచాన్ని మారుస్తోంది.
# Hindi: आर्टिफिशियल इंटेलिजेंस दुनिया को बदल रहा है।
# Tamil: செயற்கை நுண்ணறிவு உலகை மாற்றுகிறது.
# French: L'intelligence artificielle change le monde.

# %%
from deep_translator import GoogleTranslator

text = input("Enter text: ")

translated = GoogleTranslator(source="auto", target="te").translate(text)

print("Translated Text:", translated)
# Out:
# Translated Text: శుభోదయం

# %%
text = "Hello, how are you?"

translated = GoogleTranslator(source="en", target="te").translate(text)

print("Original Text:", text)
print("Translated Text:", translated)
# Out:
# Original Text: Hello, how are you?
# Translated Text: హలో, ఎలా ఉన్నారు?

# %%
from deep_translator import GoogleTranslator

# %%
import sys

# !{sys.executable} -m pip install deep-translator
# Out:
# Requirement already satisfied: deep-translator in c:\Users\bajju\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.11.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in c:\Users\bajju\AppData\Local\Programs\Python\Python314\Lib\site-packages (from deep-translator) (4.15.0)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in c:\Users\bajju\AppData\Local\Programs\Python\Python314\Lib\site-packages (from deep-translator) (2.34.2)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\Users\bajju\AppData\Local\Programs\Python\Python314\Lib\site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\Users\bajju\AppData\Local\Programs\Python\Python314\Lib\site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\bajju\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\bajju\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\bajju\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\bajju\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2026.6.17)
